# %%
# first compile the c modules where the model depends on
from explain_core.ModulesCompiler import compile_modules;
compile_modules()

# import the model engine and the model interface
from explain_core.ModelEngine import ModelEngine
from explain_core.helpers.Interface import Interface

# instantiate a model engine instance with the 'normal_neonate' model definition
model = ModelEngine("normal_neonate.json")

# get a reference to all models
models = model.models

# instantiate an interface object to interact with the model engine instance
neo = Interface(model)

# switch physiological submodels
neo.ans(True)
neo.breathing(True)
neo.metabolism(True)
neo.mob(True)
neo.placenta(False)

# switch device models
neo.ventilator(False)
neo.ecls(False)
neo.artificial_whomb(False)

# stabilize by calculating 30 seconds
neo.calculate(30)
# Out:
#  Model 'normal neonate' loaded and initialized correctly.
#  Ready in 2.5 sec. Average model step in 0.0421 ms.

# %%
neo.breathing(False)
neo.plot_time_graph(["COR.aboxy.po2","AA.pres","Heart.heart_rate"], combined=False, sharey=False, fill=True, time_to_calculate=360)
# Out:
# COR.aboxy.po2   : max    0.14726 min    0.14726
# AA.pres         : max   10.14354, min    10.1114 mmHg
# Heart.heart_rate: max    4.13219 min    4.13219

# %%
neo.get_bloodgas("COR")

# %%
neo.fastforward(120)
# Out:
#  Ready in 6.4 sec. Average model step in 0.0267 ms.

# %%
2 * (4 - 1)
# Out:
# 6

# %%
neo.get_vitals()
# Out:
# AA.pres_in      : max   75.50351, min   49.35661 mmHg
# PA.pres_in      : max    43.8267, min   23.22756 mmHg
# IVCI.pres_in    : max    8.84498, min    5.58225 mmHg
# {'heartrate': 139.38120312872528,
#  'spo2_pre': 97.86480690074151,
#  'spo2_post': 97.59428237416785,
#  'abp_systole': 75.50351,
#  'abp_diastole': 49.35661,
#  'pap_systole': 43.8267,
#  'pap_diastole': 23.22756,
#  'cvp': 6.669717909,
#  'resp_rate': 41.13017839542025,
#  'pH': 7.399978325311971,
#  'po2': 98.76562166174705,
#  'pco2': 42.425190921895265,
#  'hco3': 25.96067060908382,
#  'be': 0.701845598176624}
