# %%
# first compile the c modules where the model depends on
from explain_core.ModulesCompiler import compile_modules;
compile_modules()

# import the model engine and the model interface
from explain_core.ModelEngine import ModelEngine
from explain_core.helpers.Interface import Interface

# instantiate a model engine instance with the 'normal_neonate' model definition
model = ModelEngine("normal_neonate.json")

# get a reference to all models
models = model.models

# instantiate an interface object to interact with the model engine instance
neo = Interface(model)

# switch physiological submodels
neo.ans(False)
neo.breathing(True)
neo.metabolism(True)
neo.mob(True)
neo.placenta(False)

# switch device models
neo.ventilator(False)
neo.ecls(False)
neo.artificial_whomb(False)

# stabilize by calculating 30 seconds
neo.calculate(30)
# Out:
#  Model 'normal neonate' loaded and initialized correctly.
#  Ready in 1.5 sec. Average model step in 0.0245 ms.

# %%
neo.breathing(False)
neo.plot_time_graph(["Mob.total_vo2", "COR.aboxy.po2"], combined=False, sharey=False, fill=False, time_to_calculate=10)
# Out:
# Mob.total_vo2   : max 3352.68136 min 1123.96199
# COR.aboxy.po2   : max     8.5458 min    0.25273
