# %%
#%matplotlib ipympl  # enable this for realtime graphs

# first compile the c modules where the model depends on
from  explain_core.ModulesCompiler import compile_modules;
compile_modules()

# import the model engine and the model interface
from explain_core.ModelEngine import ModelEngine
from explain_core.helpers.Interface import Interface

# instantiate a model engine instance with the 'normal_neonate' model definition
model = ModelEngine("normal_neonate.json")

# get a reference to all the submodels
models = model.models

# instantiate an interface object to interact with the model engine instance
neo = Interface(model)

# enable or disable the physiological submodels which can be enabled or disabled.
neo.ans(True)
neo.breathing(True)
neo.metabolism(True)
neo.mob(True)

# desiable the extra-corporeal models
neo.placenta(False)
neo.ventilator(False)
neo.ecls(False)
neo.artificial_whomb(False)

# get a direct reference to the mob model
mob = models["Mob"]

# stabilize by calculating 60 seconds with fixed resp_rate of 40/min, tidal volume of 16 ml and fixed heart rate of 140 / min
neo.calculate(60)
# Out:
#  Model 'normal neonate' loaded and initialized correctly.
#  Ready in 3.6 sec. Average model step in 0.0303 ms.

# %%
neo.breathing(True)
neo.plot_time_graph(["AA.pres","AA.aboxy.so2","Heart.heart_rate", "COR.aboxy.po2"], time_to_calculate=120)
# Out:
# AA.pres         : max  107.47673, min    9.08062 mmHg
# AA.aboxy.so2    : max   97.50612 min   12.09751
# Heart.heart_rate: max   146.1281 min   11.27345
# COR.aboxy.po2   : max   39.08729 min    0.47137
